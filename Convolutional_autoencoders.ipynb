# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
# %matplotlib inline
import torch.nn as nn
import torch.nn.functional as F

# %%
#Converting data to torch.FloatTensor
transform = transforms.ToTensor()

# Download the training and test datasets
train_data = datasets.CIFAR10(root='data', train=True, download=True, transform=transform)

test_data = datasets.CIFAR10(root='data', train=False, download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data\cifar-10-python.tar.gz
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Extracting data\cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %%
#Prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=32, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32, num_workers=0)

# %% [markdown]
# # Print some random images from the dataset

# %%
#Utility functions to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  
    plt.imshow(np.transpose(img, (1, 2, 0))) 

 
#Define the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

#Obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

#Plot the images
fig = plt.figure(figsize=(8, 8))
# display 20 images
for idx in np.arange(9):
    ax = fig.add_subplot(3, 3, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# # define model

# %%
#Define the Convolutional Autoencoder
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
       
        #Encoder
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)  
        self.conv2 = nn.Conv2d(16, 4, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
       
        #Decoder
        self.t_conv1 = nn.ConvTranspose2d(4, 16, 2, stride=2)
        self.t_conv2 = nn.ConvTranspose2d(16, 3, 2, stride=2)


    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.t_conv1(x))
        x = F.sigmoid(self.t_conv2(x))
              
        return x


#Instantiate the model
model = ConvAutoencoder()
print(model)
# Out:
# ConvAutoencoder(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (t_conv1): ConvTranspose2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#   (t_conv2): ConvTranspose2d(16, 3, kernel_size=(2, 2), stride=(2, 2))
# )

# %% [markdown]
# # define optimizer and loss

# %%
#Loss function
#Binary Cross Entropy
criterion = nn.BCELoss()

# # mean-squared error loss
# criterion = nn.MSELoss()

#Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # pass model to GPU

# %%
def get_device():
    if torch.cuda.is_available():
        device = 'cuda:0'
    else:
        device = 'cpu'
    return device

device = get_device()
print(device)
model.to(device)
# Out:
# cuda:0
# ConvAutoencoder(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (t_conv1): ConvTranspose2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#   (t_conv2): ConvTranspose2d(16, 3, kernel_size=(2, 2), stride=(2, 2))
# )

# %% [markdown]
# # start training

# %%
#Epochs
n_epochs = 100

for epoch in range(1, n_epochs+1):
    # monitor training loss
    train_loss = 0.0

    #Training
    for data in train_loader:
        images, _ = data
        images = images.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, images)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*images.size(0)
          
    train_loss = train_loss/len(train_loader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch, train_loss))
# Out:
# C:\Users\hasan\anaconda3\envs\pytorch_hasan\lib\site-packages\torch\nn\functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: 1 	Training Loss: 18.768903
# Epoch: 2 	Training Loss: 18.253727
# Epoch: 3 	Training Loss: 18.188730
# Epoch: 4 	Training Loss: 18.152600
# Epoch: 5 	Training Loss: 18.130151
# Epoch: 6 	Training Loss: 18.113419
# Epoch: 7 	Training Loss: 18.102647
# Epoch: 8 	Training Loss: 18.093919
# Epoch: 9 	Training Loss: 18.086855
# Epoch: 10 	Training Loss: 18.081379
# Epoch: 11 	Training Loss: 18.077110
# Epoch: 12 	Training Loss: 18.073867
# Epoch: 13 	Training Loss: 18.071228
# Epoch: 14 	Training Loss: 18.069013
# Epoch: 15 	Training Loss: 18.067055
# Epoch: 16 	Training Loss: 18.065228
# Epoch: 17 	Training Loss: 18.063495
# Epoch: 18 	Training Loss: 18.061921
# Epoch: 19 	Training Loss: 18.060372
# Epoch: 20 	Training Loss: 18.058869
# Epoch: 21 	Training Loss: 18.057444
# Epoch: 22 	Training Loss: 18.056151
# Epoch: 23 	Training Loss: 18.054940
# Epoch: 24 	Training Loss: 18.053328
# Epoch: 25 	Training Loss: 18.052191
# Epoch: 26 	Training Loss: 18.051172
# Epoch: 27 	Training Loss: 18.050281
# Epoch: 28 	Training Loss: 18.049440
# Epoch: 29 	Training Loss: 18.048648
# Epoch: 30 	Training Loss: 18.047943
# Epoch: 31 	Training Loss: 18.047329
# Epoch: 32 	Training Loss: 18.046747
# Epoch: 33 	Training Loss: 18.046201
# Epoch: 34 	Training Loss: 18.045653
# Epoch: 35 	Training Loss: 18.045151
# Epoch: 36 	Training Loss: 18.044665
# Epoch: 37 	Training Loss: 18.044175
# Epoch: 38 	Training Loss: 18.043633
# Epoch: 39 	Training Loss: 18.043113
# Epoch: 40 	Training Loss: 18.042666
# Epoch: 41 	Training Loss: 18.042276
# Epoch: 42 	Training Loss: 18.041907
# Epoch: 43 	Training Loss: 18.041547
# Epoch: 44 	Training Loss: 18.041208
# Epoch: 45 	Training Loss: 18.040879
# Epoch: 46 	Training Loss: 18.040565
# Epoch: 47 	Training Loss: 18.040244
# Epoch: 48 	Training Loss: 18.039947
# Epoch: 49 	Training Loss: 18.039663
# Epoch: 50 	Training Loss: 18.039381
# Epoch: 51 	Training Loss: 18.039100
# Epoch: 52 	Training Loss: 18.038851
# Epoch: 53 	Training Loss: 18.038605
# Epoch: 54 	Training Loss: 18.038372
# Epoch: 55 	Training Loss: 18.038149
# Epoch: 56 	Training Loss: 18.037934
# Epoch: 57 	Training Loss: 18.037719
# Epoch: 58 	Training Loss: 18.037514
# Epoch: 59 	Training Loss: 18.037323
# Epoch: 60 	Training Loss: 18.037129
# Epoch: 61 	Training Loss: 18.036939
# Epoch: 62 	Training Loss: 18.036758
# Epoch: 63 	Training Loss: 18.036571
# Epoch: 64 	Training Loss: 18.036402
# Epoch: 65 	Training Loss: 18.036207
# Epoch: 66 	Training Loss: 18.036041
# Epoch: 67 	Training Loss: 18.035871
# Epoch: 68 	Training Loss: 18.035703
# Epoch: 69 	Training Loss: 18.035538
# Epoch: 70 	Training Loss: 18.035372
# Epoch: 71 	Training Loss: 18.035209
# Epoch: 72 	Training Loss: 18.035045
# Epoch: 73 	Training Loss: 18.034874
# Epoch: 74 	Training Loss: 18.034708
# Epoch: 75 	Training Loss: 18.034539
# Epoch: 76 	Training Loss: 18.034367
# Epoch: 77 	Training Loss: 18.034187
# Epoch: 78 	Training Loss: 18.034015
# Epoch: 79 	Training Loss: 18.033850
# Epoch: 80 	Training Loss: 18.033680
# Epoch: 81 	Training Loss: 18.033509
# Epoch: 82 	Training Loss: 18.033339
# Epoch: 83 	Training Loss: 18.033168
# Epoch: 84 	Training Loss: 18.033002
# Epoch: 85 	Training Loss: 18.032830
# Epoch: 86 	Training Loss: 18.032646
# Epoch: 87 	Training Loss: 18.032459
# Epoch: 88 	Training Loss: 18.032263
# Epoch: 89 	Training Loss: 18.032038
# Epoch: 90 	Training Loss: 18.031816
# Epoch: 91 	Training Loss: 18.031561
# Epoch: 92 	Training Loss: 18.031323
# Epoch: 93 	Training Loss: 18.031085
# Epoch: 94 	Training Loss: 18.030892
# Epoch: 95 	Training Loss: 18.030724
# Epoch: 96 	Training Loss: 18.030568
# Epoch: 97 	Training Loss: 18.030437
# Epoch: 98 	Training Loss: 18.030315
# Epoch: 99 	Training Loss: 18.030196
# Epoch: 100 	Training Loss: 18.030080

# %% [markdown]
# # Visualize some results

# %%
#Batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images = images.to(device) # pass to GPU

#Sample outputs
output = model(images) # feedforward
images = images.cpu()  # pass back to CPU 
images = images.numpy()

batch_size=32
output = output.view(batch_size, 3, 32, 32).cpu()
output = output.detach().numpy()

#Original Images
print("Original Images")
fig, axes = plt.subplots(nrows=1, ncols=5, sharex=True, sharey=True, figsize=(12,4))
for idx in np.arange(5):
    ax = fig.add_subplot(1, 5, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])
plt.show()

#Reconstructed Images
print('Reconstructed Images')
fig, axes = plt.subplots(nrows=1, ncols=5, sharex=True, sharey=True, figsize=(12,4))
for idx in np.arange(5):
    ax = fig.add_subplot(1, 5, idx+1, xticks=[], yticks=[])
    imshow(output[idx])
    ax.set_title(classes[labels[idx]])
plt.show()
# Out:
# Original Images
# Reconstructed Images
